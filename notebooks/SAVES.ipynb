# %%
# Rates for BOTH outcomes (0 and 1) by age group and sex
age_sex_rate = pd.crosstab(
    [age_bins, df['Sex']],
    df['2urvived'],
    normalize='index'
)

# Wide format: index=age group, columns=(outcome, sex)
rate_plot = age_sex_rate.unstack(fill_value=0)

# Friendly column names
rate_plot.columns = [
    f"{'Male' if sex==0 else 'Female'} - {'Died' if outcome==0 else 'Survived'}"
    for outcome, sex in rate_plot.columns
]

rate_plot.plot(kind='bar', figsize=(10,4))
plt.xlabel("Age group")
plt.ylabel("Rate")
plt.title("Death and Survival Rates by Age Group and Sex")
plt.xticks(rotation=45)
plt.legend(title="Group")
plt.show()

# %%
# Rates for BOTH outcomes (0 and 1) by age group and sex
age_sex_rate = pd.crosstab(
    [age_bins, df['Sex']],
    df['2urvived'],
    normalize='index'
)

# Wide format: index=age group, columns=(outcome, sex)
rate_plot = age_sex_rate.unstack(fill_value=0)

# Friendly column names
rate_plot.columns = [
    f"{'Male' if sex==0 else 'Female'} - {'Died' if outcome==0 else 'Survived'}"
    for outcome, sex in rate_plot.columns
]

rate_plot.plot(kind='bar', figsize=(10,4))
plt.xlabel("Age group")
plt.ylabel("Rate")
plt.title("Death and Survival Rates by Age Group and Sex")
plt.xticks(rotation=45)
plt.legend(title="Group")
plt.show()
